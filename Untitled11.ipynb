# %%
#PALLAWI KUMARI 25070123083
#EXPERIMENT9: TOOLS FOR EDA - STUDY OF NUMPY LIBRARY

# %%
#declaration of numpy
import numpy as np

a = np.array([1,10,20,30,40,50,500])
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
# Out:
# [  1  10  20  30  40  50 500]
# [[1 2 3]
#  [4 5 6]]

# %%
# dimension of array
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
#size of array
print(a.size)
print(b.size)
# Out:
# 7
# 6

# %%
a.shape
# Out:
# (7,)

# %%
b.ndim
# Out:
# 2

# %%
a.dtype
# Out:
# dtype('int64')

# %%
#in - built function using numpy
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,4)
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
print(b*2)
print(a+5)
#print(c)
#print(d)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]
# [  6  15  25  35  45  55 505]

# %%
a + 5
# Out:
# array([  6,  15,  25,  35,  45,  55, 505])

# %%
np.mean(a)
# Out:
# np.float64(93.0)

# %%
np.median(a)
# Out:
# np.float64(30.0)

# %%
np.max(a)
# Out:
# np.int64(500)

# %%
np.min(a)
# Out:
# np.int64(1)
